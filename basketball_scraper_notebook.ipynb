# %% [markdown]
# Let's get started by importing the basketball parser module and loading the player dictionary from local JSON.  We'll also load some other utility modules.  This notebook server was started with 'ipython notebook --pylab=inline'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import basketballCrawler as bc
import pandas

# %% [markdown]
# We'll load stats from the local JSON file.  This file was generated on 03/09/2013.

# %%
players = bc.loadPlayerDictionary('players.json')

# %% [markdown]
# Now, searching for a player's name (needed as a key to access the player dictionary) is done using searchForName()

# %%
bc.searchForName(players, 'James')
# Out:
# [u'James Jones',
#  u'LeBron James',
#  u'James Johnson',
#  u'James White',
#  u'Bernard James',
#  u'Mike James',
#  u'Damion James',
#  u'James Singleton',
#  u'James Anderson',
#  u'James Harden']

# %% [markdown]
# You can grab game-by-game stats with gameLogs().  Returns a pandas dataframe.  Takes a bit of time to scrape all the stats pages

# %%
lbj = bc.gameLogs(players, u'LeBron James')
kb = bc.gameLogs(players, u'Kobe Bryant')

# %%
lbj
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 864 entries, 2012-10-30 00:00:00 to 2004-04-14 00:00:00
# Data columns:
# Rk          864  non-null values
# G           864  non-null values
# Age         864  non-null values
# Tm          864  non-null values
# HomeAway    428  non-null values
# Opp         864  non-null values
# WinLoss     864  non-null values
# GS          864  non-null values
# MP          864  non-null values
# FG          864  non-null values
# FGA         864  non-null values
# FG%         864  non-null values
# 3P          864  non-null values
# 3PA         864  non-null values
# 3P%         832  non-null values
# FT          864  non-null values
# FTA         864  non-null values
# FT%         855  non-null values
# ORB         864  non-null values
# DRB         864  non-null values
# TRB         864  non-null values
# AST         864  non-null values
# STL         864  non-null values
# BLK         864  non-null values
# TOV         864  non-null values
# PF          864  non-null values
# PTS         864  non-null values
# GmSc        864  non-null values
# dtypes: float64(4), int64(18), object(6)

# %%
lbj.PTS.plot(color='black')
kb.PTS.plot(color='purple')
plt.title('Points')
